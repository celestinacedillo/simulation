# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
import pandas as pd

data = pd.read_csv('Desktop/Simulation/data/uber-raw-data-apr14.csv')

data['Date/Time'] = pd.to_datetime(df['Date/Time'])
data['Hour'] = data['Date/Time'].dt.hour
data['Day'] = data['Date/Time'].dt.day
data['Weekday'] = data['Date/Time'].dt.weekday
data['Month'] = data['Date/Time'].dt.month
data.head()
# Out:
#             Date/Time      Lat      Lon    Base  Hour  Day  Weekday  Month
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512     0    1        1      4
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512     0    1        1      4
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512     0    1        1      4
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512     0    1        1      4
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512     0    1        1      4

# %%
import plotly.express as px

sampled_data = data.sample(n=5000, random_state=41)

fig = px.density_mapbox(sampled_data, 
                        lat='Lat', 
                        lon='Lon', 
                        z=None,
                        radius=8,
                        center=dict(lat=40.73, lon=-73.93),
                        zoom=7.5,
                        mapbox_style="carto-positron",
                        height=500,
                       animation_frame = 'Hour')

fig.update_layout(
    title="Uber Pickup Density Map: Hourly Animation",
    margin=dict(l=0, r=0, t=40, b=0)
)

fig.show()
